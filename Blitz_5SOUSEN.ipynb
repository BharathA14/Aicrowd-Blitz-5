# %%
# !wget https://datasets.aicrowd.com/default/aicrowd-practice-challenges/public/sousen/v0.1/train.csv
# !wget https://datasets.aicrowd.com/default/aicrowd-practice-challenges/public/sousen/v0.1/test.zip
# Out:
# --2021-01-23 16:36:16--  https://datasets.aicrowd.com/default/aicrowd-practice-challenges/public/sousen/v0.1/train.csv
# Resolving datasets.aicrowd.com (datasets.aicrowd.com)... 35.189.208.115
# Connecting to datasets.aicrowd.com (datasets.aicrowd.com)|35.189.208.115|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-002.backblazeb2.com/aicrowd-practice-challenges/public/sousen/v0.1/train.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=002ae2491b744be0000000002%2F20210123%2Fus-west-002%2Fs3%2Faws4_request&X-Amz-Date=20210123T163618Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=a1df747ab1dec3a01ca72faa3cf9f53e0a4af2f930a7910ddc4f03b187f8ad1f [following]
# ...

# %%
import pandas as pd
from time import time
from csv import writer
from tqdm import tqdm
import os

# %%
# !unzip test
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/0.wav
#   inflating: test/1.wav
#   inflating: test/10.wav
#   inflating: test/100.wav
#   inflating: test/1000.wav
#   inflating: test/1001.wav
#   inflating: test/1002.wav
#   inflating: test/1003.wav
#   inflating: test/1004.wav
#   inflating: test/1005.wav
#   inflating: test/1006.wav
#   inflating: test/1007.wav
#   inflating: test/1008.wav
#   inflating: test/1009.wav
#   inflating: test/101.wav
#   inflating: test/1010.wav
#   inflating: test/1011.wav
#   inflating: test/1012.wav
#   inflating: test/1013.wav
#   inflating: test/1014.wav
#   inflating: test/1015.wav
#   inflating: test/1016.wav
#   inflating: test/1017.wav
#   inflating: test/1018.wav
#   inflating: test/1019.wav
#   inflating: test/102.wav
#   inflating: test/1020.wav
#   inflating: test/1021.wav
#   inflating: test/1022.wav
#   inflating: test/1023.wav
#   inflating: test/1024.wav
#   inflating: test/1025.wav
#   inflating: test/1026.wav
# ...

# %%
df = pd.read_csv('train.csv')
val = pd.read_csv('val.csv')

# %%
df.head(10)

# %%
res = [[2,i.split('.')[0]] for i in files]
print(res)
# Out:
# [[2, '4640'], [2, '3192'], [2, '2528'], [2, '4911'], [2, '4339'], [2, '1549'], [2, '2955'], [2, '3799'], [2, '2576'], [2, '490'], [2, '3675'], [2, '2572'], [2, '669'], [2, '3642'], [2, '2981'], [2, '3134'], [2, '2778'], [2, '4726'], [2, '353'], [2, '1863'], [2, '3381'], [2, '5'], [2, '677'], [2, '2714'], [2, '3243'], [2, '258'], [2, '354'], [2, '100'], [2, '2103'], [2, '4677'], [2, '1783'], [2, '1809'], [2, '386'], [2, '210'], [2, '4214'], [2, '3541'], [2, '436'], [2, '2732'], [2, '963'], [2, '1009'], [2, '2984'], [2, '649'], [2, '416'], [2, '2870'], [2, '1026'], [2, '2241'], [2, '3189'], [2, '762'], [2, '2458'], [2, '3936'], [2, '64'], [2, '1332'], [2, '3520'], [2, '2682'], [2, '591'], [2, '2927'], [2, '4572'], [2, '4083'], [2, '3891'], [2, '3403'], [2, '2176'], [2, '2549'], [2, '194'], [2, '2272'], [2, '2239'], [2, '1843'], [2, '244'], [2, '2420'], [2, '705'], [2, '3760'], [2, '2557'], [2, '667'], [2, '2346'], [2, '1157'], [2, '4865'], [2, '2362'], [2, '2574'], [2, '2360'], [2, '35
# ...

# %%
sub  = pd.DataFrame(res,columns=['label','wav_id'])
sub.head

# %%
sub.shape
# Out:
# (5000, 2)

# %%
sub.to_csv('base.csv',index=False)

# %%
files = os.listdir('/content/test')
print(files[:20])
# Out:
# ['4640.wav', '3192.wav', '2528.wav', '4911.wav', '4339.wav', '1549.wav', '2955.wav', '3799.wav', '2576.wav', '490.wav', '3675.wav', '2572.wav', '669.wav', '3642.wav', '2981.wav', '3134.wav', '2778.wav', '4726.wav', '353.wav', '1863.wav']
